# %% [markdown]
# <a href="https://colab.research.google.com/github/maker-arch/D2LExercises/blob/main/probability_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import random
import torch
from torch.distributions.multinomial import Multinomial
from d2l import torch as d2l
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1001/869719532.py in <cell line: 0>()
#       3 import torch
#       4 from torch.distributions.multinomial import Multinomial
# ----> 5 from d2l import torch as d2l
#
# ModuleNotFoundError: No module named 'd2l'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
